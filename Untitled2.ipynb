# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv

# %%
source=requests.get('https://en.wikipedia.org/wiki/Global_music_industry_market_share_data').text

# %%
soup=BeautifulSoup(source,'html.parser')

# %%
tab=pd.read_html('https://en.wikipedia.org/wiki/Global_music_industry_market_share_data',header=0)

# %%
tab
# Out:
# [    Ranking          Market  Retail value US $ (millions) Physical Digital  \
#  0       1.0   United States                        5916.1      15%     75%
#  1       2.0           Japan                        2727.5      72%     21%
#  2       3.0         Germany                        1323.1      43%     36%
#  3       4.0  United Kingdom                        1310.7      30%     50%
#  4       5.0          France                         925.1      36%     34%
#  5       6.0     South Korea                         494.4      37%     59%
#  6       7.0          Canada                         437.2      21%     65%
#  7       8.0       Australia                         412.9      19%     68%
#  8       9.0          Brazil                         295.8       5%     60%
#  9      10.0           China                         292.3       3%     90%
#  10     11.0     Netherlands                         269.5      22%     50%
# ...
