# %%
from bs4 import BeautifulSoup
import requests
import csv

# %%
source=requests.get('https://www.deccanherald.com/bengaluru').text
soup=BeautifulSoup(source,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN" "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">
# <html dir="ltr" version="XHTML+RDFa 1.0" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:article="http://ogp.me/ns/article#" xmlns:book="http://ogp.me/ns/book#" xmlns:fb="http://ogp.me/ns/fb#" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/ns/product#" xmlns:profile="http://ogp.me/ns/profile#" xmlns:video="http://ogp.me/ns/video#">
#  <head profile="http://www.w3.org/1999/xhtml/vocab">
#   <!--[if IE]><![endif]-->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <meta content="sectionpage" name="atdlayout"/>
#   <script>
#    var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
#   </script>
#   <script async="" src="https://go.automatad.com/geo/mAfXoQ/afihbs.js" type="text/javascript">
#   </script>
#   <script type="application/ld+json">
#    {
# ...

# %%
print(soup.title.text)
# Out:
# Bangalore News: Latest Bangalore News, Live Updates & Headlines | Deccan Herald

# %%
print(soup.nav)
# Out:
# <nav class="f-left" id="topmenu">
# <!--
# <ul class="h-list sanspro-reg group">
# 	    <li style = "margin-right: 14px;"> <a class="js-navAd-hamburger" href="">Menu</a></li>
#  </ul>
#  -->
# <ul class="meganizr mzr-fade h-list sanspro-reg group">
# ...

# %%
for i in soup.find_all('a'):
    print(i)
# Out:
# <a id="Top" name="Top"></a>
# <a href="/" id="logo" title="Bangalore News: Latest Bangalore News, Live Updates &amp; Headlines | Deccan Herald">
# <img alt="Bangalore News: Latest Bangalore News, Live Updates &amp; Headlines | Deccan Herald" class="normal-image js-normal-image image " src="/sites/deccanherald.com/themes/deccanherald/images/logo/d-logo.svg"/>
# <img alt="Bangalore News: Latest Bangalore News, Live Updates &amp; Headlines | Deccan Herald" class="image onscroll-image js-onscroll-image " src="/sites/deccanherald.com/themes/deccanherald/images/logo/dh-logo-white.svg"/>
# </a>
# <a href="/"><img src="/sites/deccanherald.com/themes/deccanherald/images/logo/dh-logo-white.svg" style="width: 120px; height: 25px;"/></a>
# <a href="/">Home</a>
# <a href="/bengaluru">Bengaluru</a>
# <a href="/bengaluru">Top Stories</a>
# <a href="/bengaluru#bengaluru-crime">Crime</a>
# <a href="/bengaluru#bengaluru-politics">Politics</a>
# ...

# %%
headline=soup.find('class')
print(headline)
# Out:
# None

# %%
headline=soup.find('article')

# %%
print('hello world')
# Out:
# hello world

# %%
for i in soup.find_all('div'):
    print(i.text)
# Out:
# Bangalore News: Latest Bangalore News, Live Updates & Headlines | Deccan Herald
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  HomeBengaluru Top Stories Crime Politics Infrastructure Life in the CityKarnataka Top Stories Politics DistrictsAssembly Polls 2018 Rajasthan Telangana Madhya Pradesh Chhattisgarh MizoramNational Politics North and Central South East and Northeast WestSports Cricket Football Tennis Other Sports SportsceneBusiness Business News Economy & Business Family Finance Technology DH WheelsVideos Bengaluru Karnataka People PopularOpinion Editorials Panorama Comment In Perspective Right in the MiddleFeatures Metrolife Travel Spectrum Sunday Herald Living DH Education
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Settings
#
# Logout
#
#
#
# Sign in
#
# With Facebook
# With Google
#
#
#
#
#
#
# Please fill the details to complete Sign In
#
#
# Email:
#
#
#
#
# Birthday:
#
#
#
#
#
#
#
# Gender:
#
# Choose gender
# Male
# Female
#
#
#
# Location:
#
# Choose Location
# Tumakuru
# ...

# %%
soup=BeautifulSoup(source,'lxml')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN" "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">
# <html dir="ltr" version="XHTML+RDFa 1.0" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:article="http://ogp.me/ns/article#" xmlns:book="http://ogp.me/ns/book#" xmlns:fb="http://ogp.me/ns/fb#" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/ns/product#" xmlns:profile="http://ogp.me/ns/profile#" xmlns:video="http://ogp.me/ns/video#">
# <head profile="http://www.w3.org/1999/xhtml/vocab">
# <!--[if IE]><![endif]-->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="sectionpage" name="atdlayout"/>
# <script>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# </script>
# <script async="" src="https://go.automatad.com/geo/mAfXoQ/afihbs.js" type="text/javascript"></script>
# <script type="application/ld+json">{
# ...

# %%
for i in soup.find_all('a'):
    print(i.text)
    #print(i.get('href').prettify())
# Out:
# Home
# Bengaluru
# Top Stories
# Crime
# Politics
# Infrastructure
# Life in the City
# Karnataka
# Top Stories
# Politics
# Districts
# Assembly Polls 2018
# Rajasthan
# Telangana
# Madhya Pradesh
# Chhattisgarh
# Mizoram
# National
# Politics
# North and Central
# South
# East and Northeast
# West
# Sports
# Cricket
# Football
# Tennis
# Other Sports
# Sportscene
# Business
# Business News
# Economy & Business
# Family Finance
# Technology
# DH Wheels
# Videos
# Bengaluru
# Karnataka
# People
# Popular
# Opinion
# Editorials
# Panorama
# Comment
# In Perspective
# Right in the Middle
# Features
# Metrolife
# Travel
# Spectrum
# Sunday Herald
# Living
# DH Education
#
#
#
#
# Settings
# Logout
# Sign in
# With Facebook
# With Google
#
# Cancel
# E-Paper
# Classifieds
# Newsletter
#
#
#
#
# Home
# Bengaluru
# Top Stories
# Crime
# Politics
# Infrastructure
# Life in the City
# Karnataka
# Top Stories
# Politics
# Districts
# Assembly Polls 2018
# Rajasthan
# Telangana
# ...

# %%
headline=text.h4.value
print(headline)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-4950ceb4f5c2> in <module>()
# ----> 1 headline=text.h4.value
#       2 print(headline)
#
# C:\Users\ViswanathaKrishnamur\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1805     def __getattr__(self, key):
#    1806         raise AttributeError(
# -> 1807             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1808         )
#
# AttributeError: ResultSet object has no attribute 'h4'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
source=requests.get('https://www.amazon.in/s/ref=nb_sb_ss_c_1_8?url=search-alias%3Daps&field-keywords=vivo+v9+mobile+phones&sprefix=mobile+p%2Caps%2C374&crid=3GN9U81BQ37WE').text
soup=BeautifulSoup(source,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->
# <!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->
# <!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="a-no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title dir="ltr">
#    Robot Check
#   </title>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css" rel="stylesheet"/>
#   <script>
#    if (true === true) {
#     var ue_t0 = (+ new Date()),
#         ue_csm = window,
#         ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },
# ...

# %%
for i in soup.findAll('p'):
    print(i.text)
# Out:
# Sorry, we just need to make sure you're not a robot. For best results, please make sure your browser is accepting cookies.

# %%
print(soup.body.div.div.span)
# Out:
# <span class="a-button a-button-primary a-span12">
# <span class="a-button-inner">
# <button class="a-button-text" type="submit">Continue shopping</button>
# </span>
# </span>

# %%
item=soup.findAll('div',{'class':'block sky desktopsparkle__content_Container'})
print(item)
# Out:
# []

# %%
clas=soup.findAll('div',{"id":"search-main-wrapper"})
print(clas)
# Out:
# []

# %%
clas=soup.findAll('a')
print(clas.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-7168b178e6cc> in <module>()
#       1 clas=soup.findAll('a')
# ----> 2 print(clas.text)
#
# C:\Users\ViswanathaKrishnamur\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1805     def __getattr__(self, key):
#    1806         raise AttributeError(
# -> 1807             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1808         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
from bs4 import BeautifulSoup
import requests

# %%
source=requests.get('https://timesofindia.indiatimes.com/').text

# %%
soup=BeautifulSoup(source,'html.parser')

# %%
ts = []
for i in soup.findAll('div',{"class":"top-story"}):
    print(i.text)
    ts.append(i.text)
    print(ts)
# Out:
# TOP NEWS STORIESChilli powder thrown at Delhi CM Arvind KejriwalSushma Swaraj to not contest 2019 LS pollsWe will stand up for self-respect: Virat KohliLeak of CBI chief's confidential reply irks SCOil reprieve may not last too longSBI is blocking net banking, check your accountQuick Edit: US talk on Pak's terror policy laudable
# ["TOP NEWS STORIESChilli powder thrown at Delhi CM Arvind KejriwalSushma Swaraj to not contest 2019 LS pollsWe will stand up for self-respect: Virat KohliLeak of CBI chief's confidential reply irks SCOil reprieve may not last too longSBI is blocking net banking, check your accountQuick Edit: US talk on Pak's terror policy laudable"]

# %%
print(ts)
# Out:
# ["TOP NEWS STORIESChilli powder thrown at Delhi CM Arvind KejriwalSushma Swaraj to not contest 2019 LS pollsWe will stand up for self-respect: Virat KohliLeak of CBI chief's confidential reply irks SCOil reprieve may not last too longSBI is blocking net banking, check your accountQuick Edit: US talk on Pak's terror policy laudable"]

# %%
soup.body.div.h2.text
# Out:
# "ICC rejects Pakistan's $70 million compensation claim against BCCI"

# %%
for i in soup.findAll('li',{"class":"main-story clearfix"}):
    print(i.text)
# Out:
# Deepika removes RK tattoo post wedding?
# Naagin: Bela manages to irritate the vultures
# Celebrating 1 year of Manushi Chhillar’s Miss World win
#  Power imbalances in relationship
# Bill Gates' advice to his 19-year-old self
# Do you even know if your child is diabetic?
# 10 ways ghee helps in healing
# How to make Butter Garlic Mushroom
# Appearance and reality
# First in Karnataka: Brain dead youth donates hands to
# Royal Enfield Interceptor 650, Continental GT 650
# Social Humour: Memes explode as BJP-PDP split
# HDFC disburses Rs 1,100 crore subsidy to 51,000 home
# operation khatara
# First love: Cupid does not even have that many arrows – and 20 minutes 😜
#  Neha Dhupia Gives Us The First Glimpse Of
# Judge bars US from enforcing Trump asylum ban
# Air pollution may up autism risk in children: Study
# Honey, we’ve shrunk the kids but our statues are taller
# Singapore court charges 4 NRIs over lighting fireworks on
# Do you think setting KRA's for students and teachers
# ...
