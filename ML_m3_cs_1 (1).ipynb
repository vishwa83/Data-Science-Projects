# %%
import pandas as pd

# %%
pwd
# Out:
# '/mnt/home/edureka_396003'

# %%
ls
# Out:
# 1:/
# 338_cert_proj_datasets_v3.0.csv
# 33 Lecture 3 Case Study III.ipynb
# 50_Startups.csv
# 539_cert_project_soln_v1.0.docx
# 542_Cert_Proj_Sol_v1.0.3.ipynb
# 542_Cert_Proj_Sol_v1.0.ipynb
# 542_m11_assign_sol_3_v1.0.ipynb
# 542_m3_assign_sol_1_v1.0.ipynb.ipynb
# 542_m3_assign_sol_2_v1.0.ipynb.ipynb
# 542_m3_assign_sol_3_v1.0.ipynb.ipynb
# 542_m4_assign_sol_1_v1.0.ipynb.ipynb
# 542_m4_assign_sol_2_v1.0
# 542_m4_assign_sol_2_v1.0.ipynb
# 542_m4_assign_sol_3_v1.0.ipynb
# 542_m6_cc.ipynb
# 574_m10_assign_sol_1_v3.0.ipynb
# 574_m10_assign_sol_2_v3.0.ipynb
# 574_m10_assign_sol_3_v3.0.ipynb
# 574_m11_assign_sol_1_v3.0.ipynb
# 574_m12_assign_sol_1_v3.0.ipynb
# 574_m13_assign_sol_1_v3.0.ipynb
# 574_m14_assign_sol_1_v3.0.ipynb
# 574_m14_assign_sol_2_v3.0.ipynb
# 574_m2_case_study_1_soln_v3.0.ipynb
# 574_m2_case_study_2_soln_v3.0.ipynb
# 574_m3_case_study_1_soln_v3.0.ipynb
# 574_m3_case_study_2_soln_v3.0.ipynb
# 574_m3_case_study_3_soln_v3.0.ipynb
# 574_m4_case_study_sol_1_v3.0.ipynb
# ...

# %% [markdown]
# # Load the dataset “prisoners.csv” using pandas and display the first and last five rows in the dataset

# %%
file=pd.read_csv('prisoners.csv')

# %%
file.head()
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
#
#    No. of Inmates benefitted by Higher Education  \
# 0                                            672
# 1                                              0
# 2                                             14
# ...

# %%
#f=(s)

# %% [markdown]
# # Use describe method in pandas and find out the number of columns. Can you say something about those rows who have zero inmates?  [Hint: Use the loc attribute of dataframe combined with conditional checks]

# %%
file.describe(include='all')
# Out:
#        STATE/UT    YEAR  No. of Inmates benefitted by Elementary Education  \
# count        35    35.0                                          35.000000
# unique       35     NaN                                                NaN
# top      Punjab     NaN                                                NaN
# freq          1     NaN                                                NaN
# mean        NaN  2013.0                                        1057.914286
# std         NaN     0.0                                        2078.196777
# min         NaN  2013.0                                           0.000000
# 25%         NaN  2013.0                                           0.000000
# 50%         NaN  2013.0                                         167.000000
# 75%         NaN  2013.0                                        1294.500000
# max         NaN  2013.0                                        9480.000000
#
#         No. of Inmates benefitted by Adult Education  \
# ...

# %%
colu=['No. of Inmates benefitted by Elementary Education','No. of Inmates benefitted by Adult Education','No. of Inmates benefitted by Higher Education','No. of Inmates benefitted by Computer Course']

# %%
file.loc[file['No. of Inmates benefitted by Elementary Education']<=0,:]
# Out:
#              STATE/UT  YEAR  \
# 1   Arunachal Pradesh  2013
# 15            Manipur  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 22             Sikkim  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013
#
#     No. of Inmates benefitted by Elementary Education  \
# 1                                                   0
# 15                                                  0
# 17                                                  0
# 18                                                  0
# 22                                                  0
# 29                                                  0
# 30                                                  0
# 31                                                  0
# 33                                                  0
# 34                                                  0
#
# ...

# %%
file.loc[file['No. of Inmates benefitted by Elementary Education']==0,['STATE/UT','YEAR']]
# Out:
#              STATE/UT  YEAR
# 1   Arunachal Pradesh  2013
# 15            Manipur  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 22             Sikkim  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013

# %%
file.loc[file['No. of Inmates benefitted by Adult Education']==0,['STATE/UT','YEAR']]
# Out:
#              STATE/UT  YEAR
# 1   Arunachal Pradesh  2013
# 5                 Goa  2013
# 15            Manipur  2013
# 18           Nagaland  2013
# 22             Sikkim  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013

# %%
file.loc[file['No. of Inmates benefitted by Higher Education']==0,['STATE/UT','YEAR']]
# Out:
#              STATE/UT  YEAR
# 1   Arunachal Pradesh  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 18           Nagaland  2013
# 22             Sikkim  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013

# %%
file.loc[file['No. of Inmates benefitted by Computer Course']==0,['STATE/UT','YEAR']]
# Out:
#              STATE/UT  YEAR
# 1   Arunachal Pradesh  2013
# 8    Himachal Pradesh  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 22             Sikkim  2013
# 28      A & N Islands  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013

# %% [markdown]
# # Data Manipulation:
# a. Create a new column -’total_benefitted’ that is a sum of inmates benefitted through all modes.  [Hint: Use sum method with appropriate axis]
# b. Create a new row - “totals” that is the sum of all inmates benefitted through each mode across all states.

# %%
file['total_benefitted']=file.sum(axis=1)
#file.loc['totals']=file.sum()
file.tail(10)
# Out:
#          STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 25  Uttar Pradesh  2013                                               7876
# 26    Uttaranchal  2013                                                205
# 27    West Bengal  2013                                               2023
# 28  A & N Islands  2013                                                167
# 29     Chandigarh  2013                                                  0
# 30   D & N Haveli  2013                                                  0
# 31    Daman & Diu  2013                                                  0
# 32          Delhi  2013                                               1458
# 33    Lakshadweep  2013                                                  0
# 34    Pondicherry  2013                                                  0
#
#     No. of Inmates benefitted by Adult Education  \
# 25                                          8093
# ...

# %% [markdown]
# # Make a bar plot with each state name on the x -axis and their total benefitted inmates as their bar heights. Which state has the maximum number of beneficiaries? [Hint: Use bar method of pyplot]
#
# b. Make a pie chart that depicts the ratio among different modes of benefits. [Hint: Use pie method of pyplot]

# %%
import matplotlib.pyplot as plt

# %%
file.columns
# Out:
# Index(['STATE/UT', 'YEAR', 'No. of Inmates benefitted by Elementary Education',
#        'No. of Inmates benefitted by Adult Education',
#        'No. of Inmates benefitted by Higher Education',
#        'No. of Inmates benefitted by Computer Course', 'total_benefitted'],
#       dtype='object')

# %%
#plt.figure(figsize=(20, 3))

# %%
import numpy as np
xlabels = file['STATE/UT'].values

plt.figure(figsize=(20, 3))
plt.xticks(np.arange(xlabels.shape[0]),xlabels,rotation='vertical', fontsize=10)
plt.xticks

plt.bar(np.arange(file.values.shape[0]),file['total_benefitted'],align='edge')
# Out:
# <BarContainer object of 35 artists>

# %%
plt.show()

# %%
prisoners_total = file.append(file.sum(numeric_only=True), ignore_index=True)

# %%
labels = file.columns[2:-1]
sizes = prisoners_total.iloc[-1][2:-1].values
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
sizes = prisoners_total.iloc[-1][2:-1].values
sizes
# Out:
# array([37027.0, 53720.0, 8311.0, 7356.0], dtype=object)

# %%
prisoners_total.head(10)
# Out:
#             STATE/UT    YEAR  \
# 0     Andhra Pradesh  2013.0
# 1  Arunachal Pradesh  2013.0
# 2              Assam  2013.0
# 3              Bihar  2013.0
# 4        Chhatisgarh  2013.0
# 5                Goa  2013.0
# 6            Gujarat  2013.0
# 7            Haryana  2013.0
# 8   Himachal Pradesh  2013.0
# 9    Jammu & Kashmir  2013.0
#
#    No. of Inmates benefitted by Elementary Education  \
# 0                                             9480.0
# 1                                                0.0
# 2                                              676.0
# 3                                             1693.0
# 4                                             1664.0
# 5                                                7.0
# 6                                             2310.0
# 7                                             1131.0
# 8                                               33.0
# 9                                              102.0
#
# ...
