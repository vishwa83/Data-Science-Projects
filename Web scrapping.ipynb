# %%
from bs4 import BeautifulSoup
import requests

# %%
source=requests.get('http://coreyms.com').text
soup=BeautifulSoup(source,'lxml')

# %%
article=soup.find('article')
print(article.prettify())
# Out:
# <article class="post-1536 post type-post status-publish format-standard has-post-thumbnail category-development category-python tag-computer-science tag-iterable tag-iteration tag-iterator tag-itertools tag-programming tag-video entry" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <header class="entry-header">
#   <h2 class="entry-title" itemprop="headline">
#    <a href="http://coreyms.com/development/python/python-tutorial-itertools-module-iterator-functions-for-efficient-looping" rel="bookmark">
#     Python Tutorial: Itertools Module – Iterator Functions for Efficient Looping
#    </a>
#   </h2>
#   <p class="entry-meta">
#    <time class="entry-time" datetime="2018-11-16T15:58:40+00:00" itemprop="datePublished">
#     November 16, 2018
#    </time>
#    by
#    <span class="entry-author" itemprop="author" itemscope="" itemtype="http://schema.org/Person">
#     <a class="entry-author-link" href="http://coreyms.com/author/coreymschafer" itemprop="url" rel="author">
#      <span class="entry-author-name" itemprop="name">
#       Corey Schafer
#      </span>
#     </a>
#    </span>
#    <span class="entry-comments-link">
#     <a href="http://coreyms.com/development/python/python-tutorial-itertools-module-iterator-functions-for-efficient-looping#respond">
#      <span class="dsq-postid" data-dsqidentifier="1536 http://coreyms.com/?p=1536">
#       Leave a Comment
#      </span>
#     </a>
#    </span>
#   </p>
#  </header>
#  <div class="entry-content" itemprop="text">
#   <p>
#    In this Python Programming Tutorial, we will be learning about the itertools module. The itertools module is a collection of functions that allows us to work with iterators in an efficient way. Depending on your problem, this can save you a lot of memory and also a lot of work. Let’s get started…
#   </p>
#   <p>
#    <span class="embed-youtube" style="text-align:center; display: block;">
#     <iframe allowfullscreen="true" class="youtube-player" height="360" src="https://www.youtube.com/embed/Qu3dThVy6KQ?version=3&amp;rel=1&amp;fs=1&amp;autohide=2&amp;showsearch=0&amp;showinfo=1&amp;iv_load_policy=1&amp;wmode=transparent" style="border:0;" type="text/html" width="640">
#     </iframe>
#    </span>
#   </p>
#  </div>
#  <footer class="entry-footer">
#   <p class="entry-meta">
#    <span class="entry-categories">
#     Filed Under:
#     <a href="http://coreyms.com/category/development" rel="category tag">
#      Development
#     </a>
#     ,
#     <a href="http://coreyms.com/category/development/python" rel="category tag">
#      Python
#     </a>
#    </span>
#    <span class="entry-tags">
#     Tagged With:
#     <a href="http://coreyms.com/tag/computer-science" rel="tag">
#      Computer Science
#     </a>
#     ,
#     <a href="http://coreyms.com/tag/iterable" rel="tag">
#      iterable
#     </a>
#     ,
#     <a href="http://coreyms.com/tag/iteration" rel="tag">
#      iteration
#     </a>
#     ,
#     <a href="http://coreyms.com/tag/iterator" rel="tag">
#      iterator
#     </a>
#     ,
#     <a href="http://coreyms.com/tag/itertools" rel="tag">
#      itertools
#     </a>
#     ,
#     <a href="http://coreyms.com/tag/programming" rel="tag">
#      Programming
#     </a>
#     ,
#     <a href="http://coreyms.com/tag/video" rel="tag">
#      Video
#     </a>
#    </span>
#   </p>
#  </footer>
# </article>

# %%
headline=article.h2.a.text
print(headline)
# Out:
# Python Tutorial: Itertools Module – Iterator Functions for Efficient Looping

# %%
source=requests.get('https://analyticsvidhya.com').text
soup=BeautifulSoup(source,'lxml')

# %%
print(soup.prettify())
# Out:
# <html>
#  <head lang="en-US" prefix="og: http://ogp.me/ns#">
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta charset="utf-8"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <link href="//www.google-analytics.com" rel="dns-prefetch"/>
#   <link href="https://www.analyticsvidhya.com/xmlrpc.php" rel="pingback"/>
#   <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" id="favicon" rel="icon" type="image/png"/>
#   <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon"/>
#   <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon" sizes="144x144"/>
#   <title>
#    Analytics Community | Analytics Discussions | Big Data Discussion
#   </title>
#   <meta content="Here at Analytics Vidhya, beginners or professionals feel free to ask any questions on business analytics, data science, big data, data visualizations tools &amp; techniques." name="description"/>
#   <link href="https://www.analyticsvidhya.com/" rel="canonical"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Analytics Community | Analytics Discussions | Big Data Discussion" property="og:title"/>
#   <meta content="Here at Analytics Vidhya, beginners or professionals feel free to ask any questions on business analytics, data science, big data, data visualizations tools &amp; techniques." property="og:description"/>
#   <meta content="https://www.analyticsvidhya.com/" property="og:url"/>
#   <meta content="Analytics Vidhya" property="og:site_name"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Here at Analytics Vidhya, beginners or professionals feel free to ask any questions on business analytics, data science, big data, data visualizations tools &amp; techniques." name="twitter:description"/>
#   <meta content="Analytics Community | Analytics Discussions | Big Data Discussion" name="twitter:title"/>
#   <meta content="@analyticsvidhya" name="twitter:site"/>
#   <meta content="@analyticsvidhya" name="twitter:creator"/>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"WebSite","@id":"#website","url":"https:\/\/www.analyticsvidhya.com\/","name":"Analytics Vidhya","potentialAction":{"@type":"SearchAction","target":"https:\/\/www.analyticsvidhya.com\/?s={search_term_string}","query-input":"required name=search_term_string"}}
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Organization","url":"https:\/\/www.analyticsvidhya.com\/","sameAs":["https:\/\/www.facebook.com\/AnalyticsVidhya\/","https:\/\/www.linkedin.com\/company\/analytics-vidhya","https:\/\/twitter.com\/analyticsvidhya"],"@id":"https:\/\/www.analyticsvidhya.com\/#organization","name":"Analytics Vidhya","logo":"https:\/\/www.analyticsvidhya.com\/wp-content\/uploads\/2014\/12\/analytics-logo-300x70.jpg"}
#   </script>
#   <!--[if lt IE 9]>
# <script src="//cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7/html5shiv.min.js"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/respond.js/1.3.0/respond.min.js"></script>
# <![endif]-->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-40101183-1', 'auto');
#   ga('require', 'GTM-PBZGQJ4');
#   //ga('send', 'pageview');
#   ga('send', 'pageview', {
#      'dimension1': '',
#      'dimension2': ''
#      });
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KJ969NR');
#   </script>
#   <meta content="452065408218678" property="fb:pages"/>
#   <script>
#    !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '136748720225584'); // Insert your pixel ID here.
# fbq('track', 'PageView');
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=136748720225584&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <link href="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/css/bootstrap.css" rel="stylesheet" type="text/css"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
#   <script src="https://ajax.aspnetcdn.com/ajax/modernizr/modernizr-2.7.2.js">
#   </script>
#   <script src="https://code.jquery.com/jquery-1.12.0.min.js" type="text/javascript">
#   </script>
#   <link href="https://fonts.googleapis.com/css?family=Roboto:100,100i,300,300i,400,400i,500,500i,700,700i,900,900i" rel="stylesheet"/>
#   <link href="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/css/style1.css" rel="stylesheet" type="text/css"/>
#   <link href="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/css/animate.min.css" rel="stylesheet" type="text/css"/>
#   <script src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/js/jquery.js">
#   </script>
#   <script src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/js/bootstrap.js">
#   </script>
#   <link href="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/css/hover.css" media="all" rel="stylesheet"/>
#  </head>
#  <body>
#   <div class="Wrapper2_1400 white_bg_2">
#    <div class="container-fluid">
#     <div class="row">
#      <div class="col-lg-8 col-md-8 col-sm-8 col-xs-12 tat2">
#       <a class="navbar-brand" href="https://www.analyticsvidhya.com/">
#        <img alt="logo" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/logo.png"/>
#       </a>
#      </div>
#      <div class="col-lg-2 col-md-2 col-sm-2 col-xs-6 tat2">
#       <ul class="tack-right login-anchor">
#        <li>
#        </li>
#       </ul>
#      </div>
#      <div class="col-lg-2 col-md-2 col-sm-2 col-xs-6 tat2 ">
#       <ul class="tack-left register-anchor">
#        <li>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="Wrapper_1400">
#    <div class="row tat2">
#     <div class="col-lg-10 col-md-10 col-sm-10 col-xs-12 tratrt">
#      <nav class="navbar navbar-inverse">
#       <div class="container-fluid trima">
#        <div class=" navbar-header">
#         <button class="navbar-toggle" data-target="#myNavbar" data-toggle="collapse" type="button">
#          <span class="icon-bar">
#          </span>
#          <span class="icon-bar">
#          </span>
#          <span class="icon-bar">
#          </span>
#         </button>
#        </div>
#        <div class="row collapse navbar-collapse trima" id="myNavbar">
#         <ul class="nav navbar-nav ">
#          <li class=" col-lg-2 col-md-2 col-sm-2 col-xs-12 bt1">
#           <a href="https://www.analyticsvidhya.com/blog/?utm_source=blog-navbar&amp;utm_medium=web">
#            BLOG
#           </a>
#          </li>
#          <li class=" col-lg-2 col-md-2 col-sm-2 col-xs-12 bt2">
#           <a href="https://trainings.analyticsvidhya.com/?utm_source=blog-navbar&amp;utm_medium=web">
#            LEARN
#           </a>
#          </li>
#          <li class=" col-lg-2 col-md-2 col-sm-2 col-xs-12 bt1">
#           <a href="https://discuss.analyticsvidhya.com/?utm_source=blog-navbar&amp;utm_medium=web">
#            ENGAGE
#           </a>
#          </li>
#          <li class=" col-lg-2 col-md-2 col-sm-2 col-xs-12 bt2">
#           <a href="https://datahack.analyticsvidhya.com/?utm_source=blog-navbar&amp;utm_medium=web">
#            COMPETE
#           </a>
#          </li>
#          <li class=" col-lg-2 col-md-2 col-sm-2 col-xs-12 bt1">
#           <a href="https://www.analyticsvidhya.com/jobs/?utm_source=blog-navbar&amp;utm_medium=web">
#            GET HIRED
#           </a>
#          </li>
#          <li class=" col-lg-2 col-md-2 col-sm-2 col-xs-12 bt2">
#           <a href="https://www.analyticsvidhya.com/datahack-summit-2018/?utm_source=blog-navbar&amp;utm_medium=web">
#            DATAHACK SUMMIT
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </nav>
#     </div>
#     <div class="ban">
#      <div class="deser col-lg-2 col-md-2 col-sm-2 col-xs-12 tratrt">
#       <div class="bt3">
#        <form class="navbar-form navbar" method="GET">
#         <div class="input-group tkm ">
#          <input class="creatu form-control serch " name="s" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'home_header_search', 'eventAction': 'clicked'});" placeholder="Search..." type="text"/>
#          <div class="input-group-btn float-right">
#           <button class="btn btn-default serchstyle" type="submit">
#            <i class="fa fa-search">
#            </i>
#           </button>
#          </div>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="tit2">
#    <div class="row tistring">
#     <div class="col-lg-8 col-md-8 col-sm-8 col-xs-8 tit ">
#      <a href="#">
#       <img alt="logo" class="img-responsive logo_tikra" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/logo.png"/>
#      </a>
#     </div>
#     <div class="col-lg-10 col-md-10 col-sm-10 col-xs-4 tratrt tistring">
#      <nav class="creat navbar navbar-inverse">
#       <div class="container-fluid trima tistring">
#        <div class=" navbar-header">
#         <button class="navbar-toggle" data-target="#myNavbar2" data-toggle="collapse" type="button">
#          <span class="icon-bar">
#          </span>
#          <span class="icon-bar">
#          </span>
#          <span class="icon-bar">
#          </span>
#         </button>
#        </div>
#       </div>
#      </nav>
#     </div>
#     <div class=" col-xs-12">
#      <form class="navbar-form navbar" method="GET">
#       <div class="input-group ">
#        <input class="creatu form-control serch " name="search" placeholder="Search..." type="text"/>
#        <div class="input-group-btn float-right">
#         <button class="btn btn-default serchstyle" type="submit">
#          <i class="fa fa-search">
#          </i>
#         </button>
#        </div>
#       </div>
#      </form>
#     </div>
#    </div>
#    <div class="row collapse navbar-collapse trima" id="myNavbar2">
#     <ul class="nav navbar-nav ">
#      <div class="col-lg-1 col-md-1 col-sm-1 col-xs-6 ">
#       <ul class="tack-right99 login-anchor">
#        <li>
#        </li>
#       </ul>
#      </div>
#      <div class="col-lg-1 col-md-1 col-sm-1 col-xs-6">
#       <ul class="tack-right99 register-anchor">
#        <li>
#        </li>
#       </ul>
#      </div>
#      <li class=" col-lg-2 col-md-2 col-sm-2 col-xs-12 bt1">
#       <a href="https://www.analyticsvidhya.com/blog/?utm_source=blog-navbar&amp;utm_medium=web">
#        BLOG
#       </a>
#      </li>
#      <li class=" col-lg-2 col-md-2 col-sm-2 col-xs-12 bt2">
#       <a href="https://trainings.analyticsvidhya.com/?utm_source=blog-navbar&amp;utm_medium=web">
#        LEARN
#       </a>
#      </li>
#      <li class=" col-lg-2 col-md-2 col-sm-2 col-xs-12 bt1">
#       <a href="https://discuss.analyticsvidhya.com/?utm_source=blog-navbar&amp;utm_medium=web">
#        ENGAGE
#       </a>
#      </li>
#      <li class=" col-lg-2 col-md-2 col-sm-2 col-xs-12 bt2">
#       <a href="https://datahack.analyticsvidhya.com/?utm_source=blog-navbar&amp;utm_medium=web">
#        COMPETE
#       </a>
#      </li>
#      <li class=" col-lg-2 col-md-2 col-sm-2 col-xs-12 bt1">
#       <a href="https://www.analyticsvidhya.com/jobs/?utm_source=blog-navbar&amp;utm_medium=web">
#        GET HIRED
#       </a>
#      </li>
#      <li class=" col-lg-2 col-md-2 col-sm-2 col-xs-12 bt2">
#       <a href="https://www.analyticsvidhya.com/datahack-summit-2018/?utm_source=blog-navbar&amp;utm_medium=web">
#        DATAHACK SUMMIT
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <style>
#    .slick-slide {
#   height: auto;
# }
#   </style>
#   <div class="Wrapper2_1400 white_bg_2">
#    <section class="jk-slider">
#     <div class="carousel slide" data-ride="carousel" id="carousel-example">
#      <div class="carousel-inner">
#       <div class="item active">
#        <img src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/banner3.jpg"/>
#        <div class="hero">
#         <div class="wow Zoomin ">
#          <hgroup>
#           <div class="eng">
#            <div class="wow Zoomin ">
#             <h1>
#              Creating
#              <span>
#               Nextgen
#              </span>
#              Data Science Ecosystem
#             </h1>
#            </div>
#           </div>
#           <h1>
#            LEARN | ENGAGE | COMPETE | GET HIRED
#           </h1>
#           <center class="create-account-btn">
#            <a href="https://id.analyticsvidhya.com/accounts/signup/" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'create_account', 'eventAction': 'clicked'});">
#             <button class="flipkart-navbar-button col-xs-2">
#              CREATE ACCOUNT
#             </button>
#            </a>
#           </center>
#          </hgroup>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </section>
#    <div class="engagedbg">
#     <div class="container-fluid trima">
#      <div class="texer">
#       <h3>
#        Accelerate your career through the power of Community
#       </h3>
#       <h4 class="tat4">
#        Analytics Vidhya brings you the power of community that
# comprises of data practitioners, thought leaders and
# corporates leveraging data to generate value for their
# businesses. Learn from the resources developed by experts
# at AnalyticsVidhya, participate in hackathons, master your
# skills with latest data science problems and showcase your
# skills to the world.
#       </h4>
#      </div>
#      <div class="row trisana">
#       <div class="col-lg-4 col-md-4 col-sm-4 col-xs-4">
#        <center>
#         <div class="par">
#          <h2 class="count">
#           1
#          </h2>
#          <h2>
#           <span>
#            COMMUNITY
#           </span>
#          </h2>
#         </div>
#        </center>
#       </div>
#       <div class="col-lg-4 col-md-4 col-sm-4 col-xs-4">
#        <center>
#         <div class="par">
#          <h2 class="counth2">
#           <div class="count">
#            250000
#           </div>
#           +
#          </h2>
#          <h2>
#           <span>
#            DATA SCIENTISTS
#           </span>
#          </h2>
#         </div>
#        </center>
#       </div>
#       <div class="col-lg-4 col-md-4 col-sm-4 col-xs-4">
#        <center>
#         <div class="par">
#          <h2 class="counth2">
#           <div class="count">
#            2500000
#           </div>
#           +
#          </h2>
#          <h2>
#           <span>
#            MONTHLY VISITS
#           </span>
#          </h2>
#         </div>
#        </center>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container">
#     <div class="texer2">
#      <h2>
#       Get involved with the community
#      </h2>
#      <p>
#       Data Science is a fast growing field. We help similar minded people come together and solve each other’s problem.
#      </p>
#     </div>
#     <div class="row broder tramp">
#      <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12 tit">
#       <div class="row">
#        <div class="col-lg-3 col-md-3 col-sm-3 col-xs-3 carin">
#         <a class="tabsevent" data-toggle="pill" href="#home" id="id11" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'learn_tab', 'eventAction': 'clicked'});">
#          <div class="brodern1 active" id="d_id11">
#           <h2>
#            <i aria-hidden="true" class="fa fa-book fa-book">
#            </i>
#           </h2>
#           <h3>
#            learn
#           </h3>
#          </div>
#         </a>
#        </div>
#        <div class="col-lg-3 col-md-3 col-sm-3 col-xs-3 carin">
#         <a class="tabsevent" data-toggle="pill" href="#menu1" id="id12" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'enagage_tab', 'eventAction': 'clicked'});">
#          <div class="brodern1" id="d_id12">
#           <h2>
#            <i aria-hidden="true" class="fa fa-handshake-o">
#            </i>
#           </h2>
#           <h3>
#            engage
#           </h3>
#          </div>
#         </a>
#        </div>
#        <div class="col-lg-3 col-md-3 col-sm-3 col-xs-3 carin">
#         <a class="tabsevent" data-toggle="pill" href="#menu2" id="id13" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'compete_tab', 'eventAction': 'clicked'});">
#          <div class="brodern1" id="d_id13">
#           <h2>
#            <i aria-hidden="true" class="fa fa-trophy">
#            </i>
#           </h2>
#           <h3>
#            compete
#           </h3>
#          </div>
#         </a>
#        </div>
#        <div class="col-lg-3 col-md-3 col-sm-3 col-xs-3 carin">
#         <a class="tabsevent" data-toggle="pill" href="#menu3" id="id14" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'gethired_tab', 'eventAction': 'clicked'});">
#          <div class="brodern1" id="d_id14">
#           <h2>
#            <i aria-hidden="true" class="fa fa-user-circle">
#            </i>
#           </h2>
#           <h3>
#            get hired
#           </h3>
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="col-lg-2 col-md-2 col-sm-2 col-xs-12 pills tat ">
#       <a class="tabsevent" data-toggle="pill" href="#home" id="id1" onclick="/ga('send', {'hitType': 'event', 'eventCategory': 'learn_tab', 'eventAction': 'clicked'});">
#        <div class="row brodern1 active" id="d_id1">
#         <h2>
#          <i aria-hidden="true" class="fa fa-book fa-book">
#          </i>
#         </h2>
#         <h3>
#          learn
#         </h3>
#        </div>
#       </a>
#       <a class="tabsevent" data-toggle="pill" href="#menu1" id="id2" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'enagage_tab', 'eventAction': 'clicked'});">
#        <div class="row brodern1" id="d_id2">
#         <h2>
#          <i aria-hidden="true" class="fa fa-handshake-o">
#          </i>
#         </h2>
#         <h3>
#          engage
#         </h3>
#        </div>
#       </a>
#       <a class="tabsevent" data-toggle="pill" href="#menu2" id="id3" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'compete_tab', 'eventAction': 'clicked'});">
#        <div class="row brodern1" id="d_id3">
#         <h2>
#          <i aria-hidden="true" class="fa fa-trophy">
#          </i>
#         </h2>
#         <h3>
#          compete
#         </h3>
#        </div>
#       </a>
#       <a class="tabsevent" data-toggle="pill" href="#menu3" id="id4" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'gethired_tab', 'eventAction': 'clicked'});">
#        <div class="row brodern1" id="d_id4">
#         <h2>
#          <i aria-hidden="true" class="fa fa-user-circle">
#          </i>
#         </h2>
#         <h3>
#          get hired
#         </h3>
#        </div>
#       </a>
#      </div>
#      <div class="col-lg-10 col-md-10 col-sm-10 col-xs-12 broderter ">
#       <div class="tab-content">
#        <div class="tab-pane fade active in" id="home">
#         <div class=" row carin ">
#          <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12 ">
#           <center>
#            <img class="img-responsive kirak " src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/inn2.png"/>
#           </center>
#          </div>
#          <div class="col-lg-7 col-md-7 col-sm-12 col-xs-12 carin ">
#           <h4 style="text-transform: uppercase">
#            A wide range of high quality resources at your disposal
#           </h4>
#           <p>
#            All our learning resources have been created by industry
# experts. They are simple, practical and easy to understand
# and implement - just what you need when you are learning
# something new. Check out our resources: Blog, Trainings,
# workshops and various events
#           </p>
#           <center>
#            <div class="nerwe">
#             <a href="https://www.analyticsvidhya.com/blog/" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'learn_resources', 'eventAction': 'clicked'});">
#              <button class="btn btn-hero18 btn-lg center-block" name="submit" role="button" type="submit" value="Submit">
#               Resources
#              </button>
#             </a>
#             <a href="https://trainings.analyticsvidhya.com/" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'learn_resources', 'eventAction': 'clicked'});">
#              <button class="btn btn-hero18 btn-lg tiru center-block" name="submit" role="button" type="submit" value="Submit">
#               Trainings
#              </button>
#             </a>
#            </div>
#           </center>
#          </div>
#         </div>
#        </div>
#        <div class="tab-pane fade" id="menu1">
#         <div class=" row carin ">
#          <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12 ">
#           <center>
#            <img class="img-responsive kirak" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/inn4.png"/>
#           </center>
#          </div>
#          <div class="col-lg-7 col-md-7 col-sm-12 col-xs-12 carin ">
#           <h4 style="text-transform: uppercase">
#            Engage with our community
#           </h4>
#           <p>
#            Engage with our awesome community through
# meaningful discussions, lively meet ups and
# power packed webinars
#            <br/>
#            <span>
#             The greatness of a community is most accurately measured by the compassionate actions of its members.
#            </span>
#            <br/>
#            <span>
#             - Coretta Scott King
#            </span>
#           </p>
#           <center>
#            <div class="nerwe">
#             <a href="https://discuss.analyticsvidhya.com/" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'discuss_engage', 'eventAction': 'clicked'});">
#              <button class="btn btn-hero18 btn-lg center-block" name="submit" role="button" type="submit" value="Submit">
#               Discussions
#              </button>
#             </a>
#             <a href="https://www.analyticsvidhya.com/blog/category/events/" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'events_enagage', 'eventAction': 'clicked'});">
#              <button class="btn btn-hero18 btn-lg tiru center-block" name="submit" role="button" type="submit" value="Submit">
#               Events
#              </button>
#             </a>
#            </div>
#           </center>
#          </div>
#         </div>
#        </div>
#        <div class="tab-pane fade" id="menu2">
#         <div class=" row carin ">
#          <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12 ">
#           <center>
#            <img class="img-responsive kirak" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/inn3.png"/>
#           </center>
#          </div>
#          <div class="col-lg-7 col-md-7 col-sm-12 col-xs-12 carin ">
#           <h4 style="text-transform: uppercase">
#            You Either win or you learn !
#           </h4>
#           <p>
#            What use is the knowledge without
# application to real life problems and challenges? Come and compete
# with the best data scientists across the globe in intense
# competitions. We promise you wouldn’t have experienced such intense
# yet collaborative competitions to power up your knowledge.
#           </p>
#           <a href="https://datahack.analyticsvidhya.com/contest/all/" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'competitions_compete', 'eventAction': 'clicked'});">
#            <button class="btn btn-hero18 btn-lg center-block" name="submit" role="button" type="submit" value="Submit">
#             Competitions
#            </button>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="tab-pane fade" id="menu3">
#         <div class=" row carin ">
#          <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12 ">
#           <center>
#            <img class="img-responsive kirak" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/inn1.png"/>
#           </center>
#          </div>
#          <div class="col-lg-7 col-md-7 col-sm-12 col-xs-12 carin ">
#           <h4 style="text-transform: uppercase">
#            Opportunities to work with best employers!
#           </h4>
#           <p>
#            We work with some of the best employers to bring
# exciting opportunities for our community members.
# Build your profile, engage with the community,
# compete in our competitions and we promise to bring
# you next generation opportunities
#           </p>
#           <a href="https://datahack.analyticsvidhya.com/contest/all/" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'jobs_gethired', 'eventAction': 'clicked'});">
#            <button class="btn btn-hero18 btn-lg center-block" name="submit" role="button" type="submit" value="Submit">
#             Jobs
#            </button>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container">
#     <div class="texer2">
#      <h2>
#       RECENT ARTICLES AND Tutorial
#      </h2>
#      <p>
#       High quality resources created by experts to make you a better Data Scientist
#      </p>
#      <h4>
#       blogs
#      </h4>
#     </div>
#     <div class="row slick-carousel">
#      <div class="col-lg-7 col-md-7 col-sm-12 col-xs-12">
#       <div class="featured-article big-div" style="background-image: url('https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2018/11/MC.png')">
#        <div class="block-title">
#         <a href="https://www.analyticsvidhya.com/blog/2018/11/reinforcement-learning-introduction-monte-carlo-learning-openai-gym/">
#          <input class="btn-business" type="button" value="Python"/>
#          <input class="btn-business" type="button" value="Reinforcement Learning"/>
#          <h4>
#           Reinforcement Learning: Introduction to Monte Carlo Learning using the OpenAI Gym Toolkit
#          </h4>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12">
#       <div class="featured-article small-div" style="background-image: url('https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2018/11/DHS-2018.png')">
#        <div class="block-title">
#         <a href="https://www.analyticsvidhya.com/blog/2018/11/datahack-summit-2018-build-india-nextgen-data-science-ecosystem/">
#          <input class="btn-business" type="button" value="Analytics Vidhya"/>
#          <h4>
#           DataHack Summit 2018 is Almost Here - WHERE HUMANS MEET ARTIFICIAL INTELLIGENCE
#          </h4>
#         </a>
#        </div>
#       </div>
#       <div class="featured-article small-div" style="background-image: url('https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2018/11/IMPROVING-YOUR-DEEP-NEURAL-NETWORK.jpg')">
#        <div class="block-title">
#         <a href="https://www.analyticsvidhya.com/blog/2018/11/neural-networks-hyperparameter-tuning-regularization-deeplearning/">
#          <input class="btn-business" type="button" value="Deep Learning"/>
#          <h4>
#           Improving Neural Networks - Hyperparameter Tuning, Regularization, and More (deeplearning.ai Course #2)
#          </h4>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <a href="https://www.analyticsvidhya.com/blog/">
#      <button class="btn btn-hero20 btn-lg center-block" name="submit" role="button" type="submit" value="Submit">
#       View All
#      </button>
#     </a>
#    </div>
#    <div class="container trima drean">
#     <div class="texer2 ">
#      <h2>
#       Latest competitions and practice problems
#      </h2>
#      <p>
#       May the best Data Scientist win ! Practice on our Machine Learning, Big Data, Data Science competitions till you get there
#      </p>
#     </div>
#     <div class="row">
#      <div class="col-lg-3 col-md-3 col-sm-6 col-xs-12">
#       <a href="https://datahack.analyticsvidhya.com/contest/practice-problem-intel-scene-classification-challe">
#        <center>
#         <div class="card1">
#          <h3 class="thab">
#           Practice Problem Intel Scene Classification Challenge
#          </h3>
#          <p class="pan">
#           Practice Hackathon
#          </p>
#         </div>
#        </center>
#       </a>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-6 col-xs-12">
#       <a href="https://datahack.analyticsvidhya.com/contest/jester-practice-problem">
#        <center>
#         <div class="card2">
#          <h3 class="thab">
#           Jester Practice Problem: Is this joke funny?
#          </h3>
#          <p class="pan">
#           Practice Hackathon
#          </p>
#         </div>
#        </center>
#       </a>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-6 col-xs-12">
#       <a href="https://datahack.analyticsvidhya.com/contest/practice-problem-identify-the-apparels">
#        <center>
#         <div class="card3">
#          <h3 class="thab">
#           Practice Problem: Identify the apparels
#          </h3>
#          <p class="pan">
#           Practice Hackathon
#          </p>
#         </div>
#        </center>
#       </a>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-6 col-xs-12">
#       <a href="https://datahack.analyticsvidhya.com/contest/practice-problem-recommendation-engine">
#        <center>
#         <div class="card4">
#          <h3 class="thab">
#           Practice Problem: Recommendation Engine
#          </h3>
#          <p class="pan">
#           Practice Hackathon
#          </p>
#         </div>
#        </center>
#       </a>
#      </div>
#     </div>
#     <a href="https://datahack.analyticsvidhya.com?utm_source=AVHome">
#      <button class="btn btn-hero18 btn-lg center-block" name="submit" role="button" type="submit" value="Submit">
#       View All
#      </button>
#     </a>
#    </div>
#    <div class="engagedbg">
#     <div class="container-fluid trima">
#      <div class="texer2 eng">
#       <h2>
#        Hear from our community members ...
#       </h2>
#       <p class="white">
#        How are they using Analytics Vidhya to accelerate their career?
#       </p>
#      </div>
#      <div class="row tat">
#       <div class="carousel slide" data-ride="carousel" id="myCarousel">
#        <div class="carousel-inner">
#         <div class="item active">
#          <div class="col-md-6">
#           <div class="pic">
#            <img src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/test1.png"/>
#           </div>
#           <div class="testimonial">
#            <p class="description">
#             AV is one of the best knowledge portal for Data Science
# I know about and certainly the best in India. It caters
# to the need of all sorts of people, from beginners to
# well experienced professionals. The articles are in-depth
# in nature and cover wide-variety as well which is very
# difficult to find else where. Discuss portals help people
# to clarify their doubts while hackathons give a flavor of
# real world experience. Thank you AV and keep up the good
# work.!
#            </p>
#            <center>
#             <h5 class="title">
#              SRK
#             </h5>
#            </center>
#           </div>
#          </div>
#          <div class="col-md-6">
#           <div class="pic">
#            <img src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/test2.png"/>
#           </div>
#           <div class="testimonial">
#            <p class="description">
#             I stumbled across Analytics Vidhya when I was searching for platforms that host Machine Learning and Data Science Competitions and got hooked onto it. Not only the problems that you post are interesting but covers wide variety of industry domains and has opened up new horizons. Also having a strong community helps and I have learned more from these hackathons than I would have if I had spent that time on my own. So I appreciate your effort and thank you for providing this platform to showcase our skills.
#            </p>
#            <center>
#             <h5 class="title">
#              Abhishek Sharma
#             </h5>
#            </center>
#           </div>
#          </div>
#         </div>
#         <div class="item">
#          <div class="col-md-6">
#           <div class="pic">
#            <img src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/test4.png"/>
#           </div>
#           <div class="testimonial">
#            <p class="description">
#             Articles in Analytics Vidhya are simply
# amazing. It has information about A-Z of
# analytics. Discussion forums allows one to
# clarify doubts and learn a lot. Serious
# earning happens in monthly hackathon. Each
# Hackathon will make you a better data scientist.
# In short “Think Analytics Think Analytics Vidhya
#            </p>
#            <center>
#             <h5 class="title">
#              Balaji SR
#             </h5>
#            </center>
#           </div>
#          </div>
#          <div class="col-md-6">
#           <div class="pic">
#            <img src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/test3.png"/>
#           </div>
#           <div class="testimonial">
#            <p class="description">
#             AV is the best community driven DS group out there.
# Whether its data-hacks, meetups or forums, the community is always there to help.
# Have learnt a lot being an AVian. Thanks guys :)
#            </p>
#            <center>
#             <h5 class="title">
#              Vikash
#             </h5>
#            </center>
#           </div>
#          </div>
#         </div>
#         <a class="left carousel-control" data-slide="prev" href="#myCarousel" style="margin-top: 10%;">
#          <i class="fa fa-chevron-left">
#          </i>
#         </a>
#         <a class="right carousel-control" data-slide="next" href="#myCarousel" style="margin-top: 10%;">
#          <i class="fa fa-chevron-right">
#          </i>
#         </a>
#        </div>
#        <ol class="carousel-indicators2">
#         <li class="active" data-slide-to="0" data-target="#myCarousel">
#         </li>
#         <li class="" data-slide-to="1" data-target="#myCarousel">
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="row tit">
#       <div class="carousel slide" data-ride="carousel" id="myCarousel2">
#        <div class="carousel-inner">
#         <div class="item active">
#          <div class="col-md-12">
#           <div class="pic">
#            <img src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/test1.png"/>
#           </div>
#           <div class="testimonial">
#            <p class="description">
#             AV is one of the best knowledge portal for Data Science
# I know about and certainly the best in India. It caters
# to the need of all sorts of people, from beginners to
# well experienced professionals. The articles are in-depth
# in nature and cover wide-variety as well which is very
# difficult to find else where. Discuss portals help people
# to clarify their doubts while hackathons give a flavor of
# real world experience. Thank you AV and keep up the good
# work.!
#            </p>
#            <center>
#             <h5 class="title">
#              SRK
#             </h5>
#            </center>
#           </div>
#          </div>
#         </div>
#         <div class="item">
#          <div class="col-md-12">
#           <div class="pic">
#            <img src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/test2.png"/>
#           </div>
#           <div class="testimonial">
#            <p class="description">
#             I stumbled across Analytics Vidhya when I was searching for platforms that host Machine Learning and Data Science Competitions and got hooked onto it. Not only the problems that you post are interesting but covers wide variety of industry domains and has opened up new horizons. Also having a strong community helps and I have learned more from these hackathons than I would have if I had spent that time on my own. So I appreciate your effort and thank you for providing this platform to showcase our skills.
#            </p>
#            <center>
#             <h5 class="title">
#              Abhishek Sharma
#             </h5>
#            </center>
#           </div>
#          </div>
#         </div>
#         <div class="item">
#          <div class="col-md-12">
#           <div class="pic">
#            <img src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/test4.png"/>
#           </div>
#           <div class="testimonial">
#            <p class="description">
#             Articles in Analytics Vidhya are simply
# amazing. It has information about A-Z of
# analytics. Discussion forums allows one to
# clarify doubts and learn a lot. Serious
# earning happens in monthly hackathon. Each
# Hackathon will make you a better data scientist.
# In short “Think Analytics Think Analytics Vidhya
#            </p>
#            <center>
#             <h5 class="title">
#              Balaji SR
#             </h5>
#            </center>
#           </div>
#          </div>
#         </div>
#         <div class="item">
#          <div class="col-md-12">
#           <div class="pic">
#            <img src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/test3.png"/>
#           </div>
#           <div class="testimonial">
#            <p class="description">
#             AV is the best community driven DS group out there.
# Whether its data-hacks, meetups or forums, the community is always there to help.
# Have learnt a lot being an AVian. Thanks guys :)
#            </p>
#            <center>
#             <h5 class="title">
#              Vikash
#             </h5>
#            </center>
#           </div>
#          </div>
#         </div>
#         <a class="left carousel-control" data-slide="prev" href="#myCarousel2" style="margin-top: 10%;">
#          <i class="fa fa-chevron-left">
#          </i>
#         </a>
#         <a class="right carousel-control" data-slide="next" href="#myCarousel2" style="margin-top: 10%;">
#          <i class="fa fa-chevron-right">
#          </i>
#         </a>
#        </div>
#        <ol class="carousel-indicators2">
#         <li class="active" data-slide-to="0" data-target="#myCarousel2">
#         </li>
#         <li class="" data-slide-to="1" data-target="#myCarousel2">
#         </li>
#        </ol>
#       </div>
#      </div>
#     </div>
#    </div>
#    <section>
#     <div class="comapnies">
#      <div class="texer2">
#       <div class="wow Zoomin" style="visibility: visible; animation-name: zoomIn;">
#        <h2>
#         Companies we are working with
#        </h2>
#        <p>
#         We're driving growth and innovation at the global headquarters of the world's largest
#         <br/>
#         Data Science company!
#        </p>
#       </div>
#      </div>
#      <div class="container-fluid tat">
#       <div class="carousel slide media-carousel" id="media">
#        <div class="carousel-inner">
#         <div class="item active">
#          <div class="row">
#           <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6">
#            <a class="img-responsive" href="#">
#             <img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg16.png"/>
#            </a>
#           </div>
#           <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6">
#            <a class="img-responsive" href="#">
#             <img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg2.png"/>
#            </a>
#           </div>
#           <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6">
#            <a class="img-responsive" href="#">
#             <img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg4.png"/>
#            </a>
#           </div>
#           <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6">
#            <a class="img-responsive" href="#">
#             <img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg13.png"/>
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="item">
#          <div class="row">
#           <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6">
#            <a class="img-responsive" href="#">
#             <img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg3.png"/>
#            </a>
#           </div>
#           <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6">
#            <a class="img-responsive" href="#">
#             <img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg6.png"/>
#            </a>
#           </div>
#           <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6">
#            <a class="img-responsive" href="#">
#             <img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg15.png"/>
#            </a>
#           </div>
#           <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6">
#            <a class="img-responsive" href="#">
#             <img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg12.png"/>
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="item">
#          <div class="row">
#           <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6">
#            <a class="img-responsive" href="#">
#             <img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg1.png"/>
#            </a>
#           </div>
#          </div>
#         </div>
#         <a class="left carousel-control" data-slide="prev" href="#media">
#          ‹
#         </a>
#         <a class="right carousel-control" data-slide="next" href="#media">
#          ›
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="container-fluid tit">
#       <div class="carousel slide media-carousel" id="media2">
#        <div class="carousel-inner">
#         <div class="item active">
#          <div class="row">
#           <div class="col-lg-6 col-md-6 col-sm-6 col-xs-6">
#            <center>
#             <a href="#">
#              <img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg16.png"/>
#             </a>
#            </center>
#           </div>
#           <div class="col-lg-6 col-md-6 col-sm-6 col-xs-6">
#            <center>
#             <a href="#">
#              <img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg2.png"/>
#             </a>
#            </center>
#           </div>
#          </div>
#         </div>
#         <div class="item">
#          <div class="row">
#           <div class="col-lg-6 col-md-6 col-sm-6 col-xs-6">
#            <center>
#             <a href="#">
#              <img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg4.png"/>
#             </a>
#            </center>
#           </div>
#           <div class="col-lg-6 col-md-6 col-sm-6 col-xs-6">
#            <center>
#             <a href="#">
#              <img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg13.png"/>
#             </a>
#            </center>
#           </div>
#          </div>
#         </div>
#         <div class="item">
#          <div class="row">
#           <div class="col-lg-6 col-md-6 col-sm-6 col-xs-6">
#            <center>
#             <a href="#">
#              <img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg3.png"/>
#             </a>
#            </center>
#           </div>
#           <div class="col-lg-6 col-md-6 col-sm-6 col-xs-6">
#            <center>
#             <a href="#">
#              <img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg6.png"/>
#             </a>
#            </center>
#           </div>
#          </div>
#         </div>
#         <div class="item">
#          <div class="row">
#           <div class="col-lg-6 col-md-6 col-sm-6 col-xs-6">
#            <center>
#             <a href="#">
#              <img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg15.png"/>
#             </a>
#            </center>
#           </div>
#           <div class="col-lg-6 col-md-6 col-sm-6 col-xs-6">
#            <center>
#             <a href="#">
#              <img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg12.png"/>
#             </a>
#            </center>
#           </div>
#          </div>
#         </div>
#         <div class="item">
#          <div class="row">
#           <div class="col-lg-6 col-md-6 col-sm-6 col-xs-6">
#            <center>
#             <a href="#">
#              <img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg1.png"/>
#             </a>
#            </center>
#           </div>
#          </div>
#         </div>
#        </div>
#        <a class="left carousel-control" data-slide="prev" href="#media2">
#         ‹
#        </a>
#        <a class="right carousel-control" data-slide="next" href="#media2">
#         ›
#        </a>
#       </div>
#      </div>
#      <a href="https://www.analyticsvidhya.com/corporate?utm_source=AVHome">
#       <button class="btn btn-hero20 btn-lg center-block" name="submit" role="button" type="submit" value="Submit">
#        View All
#       </button>
#      </a>
#     </div>
#    </section>
#   </div>
#   <div class="Wrapper2_1400">
#    <footer>
#     <div id="footer">
#      <div class="footer-container">
#       <div class="upper-footer">
#        <div class="logo">
#         <img class="footer-logo" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/logofooter.png"/>
#        </div>
#        <div class="navigation-content">
#         <div class="footer-links-holder">
#          <h5 class="links-hide">
#           ANALYTICS VIDHYA
#          </h5>
#          <ul class="footer-links av-links">
#           <li>
#            <a href="https://www.analyticsvidhya.com/about-me/" target="_blank">
#             About Us
#            </a>
#           </li>
#           <li>
#            <a href="https://www.analyticsvidhya.com/about-me/team/" target="_blank">
#             Our Team
#            </a>
#           </li>
#           <li>
#            <a href="https://www.analyticsvidhya.com/career-analytics-vidhya/" target="_blank">
#             Career
#            </a>
#           </li>
#           <li>
#            <a href="https://www.analyticsvidhya.com/contact/" target="_blank">
#             Contact Us
#            </a>
#           </li>
#           <li>
#            <a href="https://www.analyticsvidhya.com/about-me/write/" target="_blank">
#             Write for us
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="mobile-links-holder">
#          <div class="links">
#           <a href="https://www.analyticsvidhya.com/about-me/" target="_blank">
#            About Us
#           </a>
#          </div>
#          <div class="links">
#           <a href="https://www.analyticsvidhya.com/about-me/team/" target="_blank">
#            •
#           </a>
#          </div>
#          <div class="links">
#           <a href="https://www.analyticsvidhya.com/about-me/team/" target="_blank">
#            Our Team
#           </a>
#          </div>
#          <div class="links">
#           <a href="https://www.analyticsvidhya.com/about-me/team/" target="_blank">
#            •
#           </a>
#          </div>
#          <div class="links">
#           <a href="https://www.analyticsvidhya.com/career-analytics-vidhya/" target="_blank">
#            Careers
#           </a>
#          </div>
#          <div class="links">
#           <a href="https://www.analyticsvidhya.com/about-me/team/" target="_blank">
#            •
#           </a>
#          </div>
#          <div class="links">
#           <a href="https://www.analyticsvidhya.com/contact/" target="_blank">
#            Contact Us
#           </a>
#          </div>
#         </div>
#         <div class="footer-links-holder">
#          <h5 class="links-show">
#           DATA SCIENTISTS
#          </h5>
#          <ul class="footer-links">
#           <li>
#            <a href="https://www.analyticsvidhya.com/blog" target="_blank">
#             Blog
#            </a>
#           </li>
#           <li>
#            <a href="https://datahack.analyticsvidhya.com/" target="_blank">
#             Hackathon
#            </a>
#           </li>
#           <li>
#            <a href="https://discuss.analyticsvidhya.com/" target="_blank">
#             Discussions
#            </a>
#           </li>
#           <li>
#            <a href="https://www.analyticsvidhya.com/jobs/" target="_blank">
#             Apply Jobs
#            </a>
#           </li>
#           <li>
#            <a href="https://datahack.analyticsvidhya.com/users/" target="_blank">
#             Leaderboard
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="footer-links-holder">
#          <h5 class="links-show">
#           COMPANIES
#          </h5>
#          <ul class="footer-links">
#           <li>
#            <a href="https://www.analyticsvidhya.com/corporate/" target="_blank">
#             Post Jobs
#            </a>
#           </li>
#           <li>
#            <a href="https://trainings.analyticsvidhya.com" target="_blank">
#             Trainings
#            </a>
#           </li>
#           <li>
#            <a href="https://datahack.analyticsvidhya.com/" target="_blank">
#             Hiring Hackathons
#            </a>
#           </li>
#           <li>
#            <a href="https://www.analyticsvidhya.com/contact/" target="_blank">
#             Advertising
#            </a>
#           </li>
#           <li>
#            <a href="https://www.analyticsvidhya.com/contact/" target="_blank">
#             Reach Us
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="mobile-signup">
#         <p>
#          Don't have an account?
#          <a class="signup-link" href="https://datahack.analyticsvidhya.com/signup/" target="_blank">
#           Sign up
#          </a>
#          here.
#         </p>
#        </div>
#        <div class="footer-social">
#         <div class="join">
#          <h5>
#           JOIN OUR COMMUNITY :
#          </h5>
#         </div>
#         <div class="social-stats">
#          <div class="social" id="wrapper">
#           <a class="item facebook" href="https://www.facebook.com/AnalyticsVidhya/" target="_blank">
#            <i class="fa fa-facebook social-img">
#            </i>
#           </a>
#           <a class="item facebook" href="https://www.facebook.com/AnalyticsVidhya/" target="_blank">
#            <span class="count2_followers" id="followers-count2">
#             46336
#            </span>
#           </a>
#           <a class="item facebook" href="https://www.facebook.com/AnalyticsVidhya/" target="_blank">
#            <span id="followers">
#             Followers
#            </span>
#           </a>
#          </div>
#          <div class="social" id="wrapper">
#           <a class="item twitter" href="https://twitter.com/analyticsvidhya" target="_blank">
#            <i class="fa fa-twitter social-img">
#            </i>
#           </a>
#           <a class="item twitter" href="https://twitter.com/analyticsvidhya" target="_blank">
#            <span class="count2_followers" id="followers-count2">
#             18659
#            </span>
#           </a>
#           <a class="item twitter" href="https://twitter.com/analyticsvidhya" target="_blank">
#            <span id="followers">
#             Followers
#            </span>
#           </a>
#          </div>
#          <div class="social" id="wrapper">
#           <a class="item google" href="https://plus.google.com/+Analyticsvidhya" target="_blank">
#            <i class="fa fa-google-plus social-img">
#            </i>
#           </a>
#           <a class="item google" href="https://plus.google.com/+Analyticsvidhya" target="_blank">
#            <span class="count2_followers" id="followers-count2">
#             3027
#            </span>
#           </a>
#           <a class="item google" href="https://plus.google.com/+Analyticsvidhya" target="_blank">
#            <span id="followers">
#             Followers
#            </span>
#           </a>
#          </div>
#          <div class="social" id="wrapper">
#           <a class="item linkedin" href="https://www.linkedin.com/m/login/" target="_blank">
#            <i class="fa fa-linkedin social-img">
#            </i>
#           </a>
#           <a class="item linkedin" href="https://www.linkedin.com/m/login/" target="_blank">
#            <span class="count2_followers" id="followers-count2">
#             7513
#            </span>
#           </a>
#           <a class="item linkedin" href="https://www.linkedin.com/m/login/" target="_blank">
#            <span id="followers">
#             Followers
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="subscribe">
#          <form action="https://feedburner.google.com/fb/a/mailverify" method="post" target="_blank">
#           <input name="uri" type="hidden" value="analyticsvidhya"/>
#           <input name="loc" type="hidden" value="en_US"/>
#           <input class="subscriber" id="footer-email" name="email" placeholder="  Subscribe to emailer" type="email"/>
#           <input class="subscriber-button" type="submit" value="&gt;"/>
#          </form>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div id="lower">
#      <div class="container2">
#       <div class="lower-footer">
#        <p>
#         © Copyright 2013-2018 Analytics Vidhya.
#        </p>
#        <ul class="lower-footer-links">
#         <li>
#          <a href="https://www.analyticsvidhya.com/privacy-policy/" target="_blank">
#           Privacy Policy
#          </a>
#         </li>
#         <li>
#          <a href="https://www.analyticsvidhya.com/terms/" target="_blank">
#           Terms of Use
#          </a>
#         </li>
#         <li>
#          <a href="https://www.analyticsvidhya.com/refund-policy/" target="_blank">
#           Refund Policy
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="sign-up">
#        <p>
#         Don't have an account?
#         <a class="signup-link" href="https://id.analyticsvidhya.com/accounts/signup/" target="_blank">
#          Sign up
#         </a>
#        </p>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <script>
#    $(document).ready(function(){
#   $(".tabsevent").on("click", function(){
#       $(".brodern1").removeClass("active");
#       // First get "a" tag id
#       var id = $(this).attr('id');
#       if(id == "id1")
#         {
#           $("#d_id1").addClass("active");
#         }
#         if(id == "id2")
#           {
#             $("#d_id2").addClass("active");
#           }
#           if(id == "id3")
#             {
#               $("#d_id3").addClass("active");
#             }
#             if(id == "id4")
#               {
#                 $("#d_id4").addClass("active");
#               }
#               if(id == "id11")
#                 {
#                   $("#d_id11").addClass("active");
#                 }
#                 if(id == "id12")
#                   {
#                     $("#d_id12").addClass("active");
#                   }
#                   if(id == "id13")
#                     {
#                       $("#d_id13").addClass("active");
#                     }
#                     if(id == "id14")
#                       {
#                         $("#d_id14").addClass("active");
#                       }
#
#   });
#   });
#   </script>
#   <script type="text/javascript">
#    jQuery(document).ready(function(){
#        jQuery('.footer-links-holder .links-show').click(function () {
#        jQuery(this).parent().toggleClass('active');
#      });
#    });
#   </script>
#   <script>
#    // Dropdown menu hover
# $('.dropdown .dropdown-menu').hover(function(){
#     $(this).siblings('a').css('background-color','#154376');
#     $(this).siblings('a').css('color','#fff');
# }, function(){
#     $(this).siblings('a').css('background-color','#fff');
#     $(this).siblings('a').css('color','#000');
# });
#   </script>
#   <script>
#    var i=1;
# function animate(){
#     $('#animation'+i).delay(2000).fadeIn(2000,function(){$('.animation').fadeOut(2000)});
# 	i = i+1;
# 	if(i==7){
# 		i=1;
#     }
# 	window.setTimeout(function() {animate()},2000);
# }
# $(document).ready(function(){
#   animate();
# })
#   </script>
#   <script>
#    $(document).ready(function(){
# 	$('.radio_click').click(function () {
# 		$('.side-course').css("color", "#000");
# 		var click_id = $(this).attr('id');
# 		var id_number = click_id.slice(5);
# 		$('#pitem'+id_number).css("color", "#02A1A5");
# 	});
# });
#   </script>
#   <script>
#    $(document).ready(function(){
#      $(window).scroll(function () {
#             if ($(this).scrollTop() > 50) {
#                 $('#back-to-top').fadeIn();
#             } else {
#                 $('#back-to-top').fadeOut();
#             }
#         });
#         // scroll body to 0px on click
#         $('#back-to-top').click(function () {
#             $('#back-to-top').tooltip('hide');
#             $('body,html').animate({
#                 scrollTop: 0
#             }, 800);
#             return false;
#         });
#
#         $('#back-to-top').tooltip('show');
#
# });
#   </script>
#   <script>
#    $(document).ready(function(){
#     $(".submenu1").hide();
#     $("#menu1").click(function(){
#         $(".submenu1").toggle();
#     });
# });
#   </script>
#   <script>
#    function reverseString(str) {
#  array = str.split("");
#  array.reverse();
#  str = array.join('');
#  return str;
# }
# var count_done = 0;
# $(window).scroll(function(){
#   if($(this).scrollTop() > $('.engagedbg').offset()['top'] - 200 && count_done==0){
#     $('.count').each(function () {
#         $(this).prop('Counter',0).animate({
#             Counter: $(this).text()
#         }, {
#             duration: 1000,
#             easing: 'swing',
#             step: function (now) {
#                 $(this).text(Math.ceil(now));
#             }
#         });
#         count_done = 1;
#     });
#     setTimeout(function(){
#       $('.count').each(function(){
#       var a = $(this).text();
#       a = reverseString(a);
#       var b = a.match(/.{1,3}/g);
#       a = b.join(',')
#       a = reverseString(a);
#       $(this).text(a);
#     });
#   },1100);
#   }
# });
#   </script>
#  </body>
# </html>

# %%
print(soup.find_all('a'))
for a in find_all('a'):
    print(a.get('href').prettify())
# Out:
# [<a class="navbar-brand" href="https://www.analyticsvidhya.com/"><img alt="logo" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/logo.png"/></a>, <a href="https://www.analyticsvidhya.com/blog/?utm_source=blog-navbar&amp;utm_medium=web">BLOG</a>, <a href="https://trainings.analyticsvidhya.com/?utm_source=blog-navbar&amp;utm_medium=web">LEARN</a>, <a href="https://discuss.analyticsvidhya.com/?utm_source=blog-navbar&amp;utm_medium=web">ENGAGE</a>, <a href="https://datahack.analyticsvidhya.com/?utm_source=blog-navbar&amp;utm_medium=web">COMPETE</a>, <a href="https://www.analyticsvidhya.com/jobs/?utm_source=blog-navbar&amp;utm_medium=web">GET HIRED</a>, <a href="https://www.analyticsvidhya.com/datahack-summit-2018/?utm_source=blog-navbar&amp;utm_medium=web">DATAHACK SUMMIT</a>, <a href="#"><img alt="logo" class="img-responsive logo_tikra" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/logo.png"/></a>, <a href="https://www.analyticsvidhya.com/blog/?utm_source=blog-navbar&amp;utm_medium=web">BLOG</a>, <a href="https://trainings.analyticsvidhya.com/?utm_source=blog-navbar&amp;utm_medium=web">LEARN</a>, <a href="https://discuss.analyticsvidhya.com/?utm_source=blog-navbar&amp;utm_medium=web">ENGAGE</a>, <a href="https://datahack.analyticsvidhya.com/?utm_source=blog-navbar&amp;utm_medium=web">COMPETE</a>, <a href="https://www.analyticsvidhya.com/jobs/?utm_source=blog-navbar&amp;utm_medium=web">GET HIRED</a>, <a href="https://www.analyticsvidhya.com/datahack-summit-2018/?utm_source=blog-navbar&amp;utm_medium=web">DATAHACK SUMMIT</a>, <a href="https://id.analyticsvidhya.com/accounts/signup/" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'create_account', 'eventAction': 'clicked'});"><button class="flipkart-navbar-button col-xs-2">CREATE ACCOUNT </button></a>, <a class="tabsevent" data-toggle="pill" href="#home" id="id11" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'learn_tab', 'eventAction': 'clicked'});"><div class="brodern1 active" id="d_id11">
# <h2> <i aria-hidden="true" class="fa fa-book fa-book"></i></h2>
# <h3>learn</h3>
# </div></a>, <a class="tabsevent" data-toggle="pill" href="#menu1" id="id12" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'enagage_tab', 'eventAction': 'clicked'});"><div class="brodern1" id="d_id12">
# <h2> <i aria-hidden="true" class="fa fa-handshake-o"></i></h2>
# <h3>engage</h3>
# </div></a>, <a class="tabsevent" data-toggle="pill" href="#menu2" id="id13" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'compete_tab', 'eventAction': 'clicked'});"><div class="brodern1" id="d_id13">
# <h2> <i aria-hidden="true" class="fa fa-trophy"></i></h2>
# <h3>compete</h3>
# </div></a>, <a class="tabsevent" data-toggle="pill" href="#menu3" id="id14" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'gethired_tab', 'eventAction': 'clicked'});"><div class="brodern1" id="d_id14">
# <h2> <i aria-hidden="true" class="fa fa-user-circle"></i></h2>
# <h3>get hired</h3>
# </div></a>, <a class="tabsevent" data-toggle="pill" href="#home" id="id1" onclick="/ga('send', {'hitType': 'event', 'eventCategory': 'learn_tab', 'eventAction': 'clicked'});"><div class="row brodern1 active" id="d_id1">
# <h2> <i aria-hidden="true" class="fa fa-book fa-book"></i></h2>
# <h3>learn</h3>
# </div></a>, <a class="tabsevent" data-toggle="pill" href="#menu1" id="id2" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'enagage_tab', 'eventAction': 'clicked'});"><div class="row brodern1" id="d_id2">
# <h2><i aria-hidden="true" class="fa fa-handshake-o"></i></h2>
# <h3>engage</h3>
# </div></a>, <a class="tabsevent" data-toggle="pill" href="#menu2" id="id3" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'compete_tab', 'eventAction': 'clicked'});"><div class="row brodern1" id="d_id3">
# <h2> <i aria-hidden="true" class="fa fa-trophy"></i></h2>
# <h3>compete</h3>
# </div></a>, <a class="tabsevent" data-toggle="pill" href="#menu3" id="id4" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'gethired_tab', 'eventAction': 'clicked'});"><div class="row brodern1" id="d_id4">
# <h2><i aria-hidden="true" class="fa fa-user-circle"></i></h2>
# <h3>get hired</h3>
# </div></a>, <a href="https://www.analyticsvidhya.com/blog/" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'learn_resources', 'eventAction': 'clicked'});"> <button class="btn btn-hero18 btn-lg center-block" name="submit" role="button" type="submit" value="Submit">Resources</button></a>, <a href="https://trainings.analyticsvidhya.com/" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'learn_resources', 'eventAction': 'clicked'});"> <button class="btn btn-hero18 btn-lg tiru center-block" name="submit" role="button" type="submit" value="Submit">Trainings</button></a>, <a href="https://discuss.analyticsvidhya.com/" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'discuss_engage', 'eventAction': 'clicked'});"> <button class="btn btn-hero18 btn-lg center-block" name="submit" role="button" type="submit" value="Submit">Discussions</button></a>, <a href="https://www.analyticsvidhya.com/blog/category/events/" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'events_enagage', 'eventAction': 'clicked'});"> <button class="btn btn-hero18 btn-lg tiru center-block" name="submit" role="button" type="submit" value="Submit">Events</button></a>, <a href="https://datahack.analyticsvidhya.com/contest/all/" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'competitions_compete', 'eventAction': 'clicked'});"> <button class="btn btn-hero18 btn-lg center-block" name="submit" role="button" type="submit" value="Submit">Competitions</button></a>, <a href="https://datahack.analyticsvidhya.com/contest/all/" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'jobs_gethired', 'eventAction': 'clicked'});"> <button class="btn btn-hero18 btn-lg center-block" name="submit" role="button" type="submit" value="Submit">Jobs</button></a>, <a href="https://www.analyticsvidhya.com/blog/2018/11/reinforcement-learning-introduction-monte-carlo-learning-openai-gym/">
# <input class="btn-business" type="button" value="Python"/>
# <input class="btn-business" type="button" value="Reinforcement Learning"/>
# <h4>Reinforcement Learning: Introduction to Monte Carlo Learning using the OpenAI Gym Toolkit</h4>
# </a>, <a href="https://www.analyticsvidhya.com/blog/2018/11/datahack-summit-2018-build-india-nextgen-data-science-ecosystem/">
# <input class="btn-business" type="button" value="Analytics Vidhya"/>
# <h4>DataHack Summit 2018 is Almost Here - WHERE HUMANS MEET ARTIFICIAL INTELLIGENCE</h4>
# </a>, <a href="https://www.analyticsvidhya.com/blog/2018/11/neural-networks-hyperparameter-tuning-regularization-deeplearning/">
# <input class="btn-business" type="button" value="Deep Learning"/>
# <h4>Improving Neural Networks - Hyperparameter Tuning, Regularization, and More (deeplearning.ai Course #2)</h4>
# </a>, <a href="https://www.analyticsvidhya.com/blog/"><button class="btn btn-hero20 btn-lg center-block" name="submit" role="button" type="submit" value="Submit">View All</button></a>, <a href="https://datahack.analyticsvidhya.com/contest/practice-problem-intel-scene-classification-challe">
# <center> <div class="card1">
# <h3 class="thab">Practice Problem Intel Scene Classification Challenge</h3>
# <p class="pan">Practice Hackathon </p>
# </div></center>
# </a>, <a href="https://datahack.analyticsvidhya.com/contest/jester-practice-problem">
# <center> <div class="card2">
# <h3 class="thab">Jester Practice Problem: Is this joke funny?</h3>
# <p class="pan">Practice Hackathon </p>
# </div></center>
# </a>, <a href="https://datahack.analyticsvidhya.com/contest/practice-problem-identify-the-apparels">
# <center> <div class="card3">
# <h3 class="thab">Practice Problem: Identify the apparels</h3>
# <p class="pan">Practice Hackathon </p>
# </div></center>
# </a>, <a href="https://datahack.analyticsvidhya.com/contest/practice-problem-recommendation-engine">
# <center> <div class="card4">
# <h3 class="thab">Practice Problem: Recommendation Engine</h3>
# <p class="pan">Practice Hackathon </p>
# </div></center>
# </a>, <a href="https://datahack.analyticsvidhya.com?utm_source=AVHome"><button class="btn btn-hero18 btn-lg center-block" name="submit" role="button" type="submit" value="Submit">View All</button></a>, <a class="left carousel-control" data-slide="prev" href="#myCarousel" style="margin-top: 10%;">
# <i class="fa fa-chevron-left"></i>
# </a>, <a class="right carousel-control" data-slide="next" href="#myCarousel" style="margin-top: 10%;">
# <i class="fa fa-chevron-right"></i>
# </a>, <a class="left carousel-control" data-slide="prev" href="#myCarousel2" style="margin-top: 10%;">
# <i class="fa fa-chevron-left"></i>
# </a>, <a class="right carousel-control" data-slide="next" href="#myCarousel2" style="margin-top: 10%;">
# <i class="fa fa-chevron-right"></i>
# </a>, <a class="img-responsive" href="#"><img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg16.png"/></a>, <a class="img-responsive" href="#"><img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg2.png"/></a>, <a class="img-responsive" href="#"><img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg4.png"/></a>, <a class="img-responsive" href="#"><img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg13.png"/></a>, <a class="img-responsive" href="#"><img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg3.png"/></a>, <a class="img-responsive" href="#"><img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg6.png"/></a>, <a class="img-responsive" href="#"><img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg15.png"/></a>, <a class="img-responsive" href="#"><img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg12.png"/></a>, <a class="img-responsive" href="#"><img alt="" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg1.png"/></a>, <a class="left carousel-control" data-slide="prev" href="#media">‹</a>, <a class="right carousel-control" data-slide="next" href="#media">›</a>, <a href="#"><img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg16.png"/> </a>, <a href="#"><img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg2.png"/> </a>, <a href="#"><img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg4.png"/> </a>, <a href="#"><img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg13.png"/> </a>, <a href="#"><img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg3.png"/> </a>, <a href="#"><img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg6.png"/> </a>, <a href="#"><img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg15.png"/> </a>, <a href="#"><img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg12.png"/> </a>, <a href="#"><img alt="" class="img-responsive" src="https://www.analyticsvidhya.com/wp-content/themes/Curated/custom-design/images/lg1.png"/> </a>, <a class="left carousel-control" data-slide="prev" href="#media2">‹</a>, <a class="right carousel-control" data-slide="next" href="#media2">›</a>, <a href="https://www.analyticsvidhya.com/corporate?utm_source=AVHome"><button class="btn btn-hero20 btn-lg center-block" name="submit" role="button" type="submit" value="Submit">View All</button></a>, <a href="https://www.analyticsvidhya.com/about-me/" target="_blank">About Us</a>, <a href="https://www.analyticsvidhya.com/about-me/team/" target="_blank">Our Team</a>, <a href="https://www.analyticsvidhya.com/career-analytics-vidhya/" target="_blank">Career</a>, <a href="https://www.analyticsvidhya.com/contact/" target="_blank">Contact Us</a>, <a href="https://www.analyticsvidhya.com/about-me/write/" target="_blank">Write for us</a>, <a href="https://www.analyticsvidhya.com/about-me/" target="_blank">About Us</a>, <a href="https://www.analyticsvidhya.com/about-me/team/" target="_blank">•</a>, <a href="https://www.analyticsvidhya.com/about-me/team/" target="_blank">Our Team</a>, <a href="https://www.analyticsvidhya.com/about-me/team/" target="_blank">•</a>, <a href="https://www.analyticsvidhya.com/career-analytics-vidhya/" tar ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-f211ef877561> in <module>()
#       1 print(soup.find_all('a'))
# ----> 2 for a in find_all('a'):
#       3     print(a.get('href').prettify())
#
# NameError: name 'find_all' is not defined

# %%
#body=soup.body
for a in soup.find_all('div',class_='body'):
    print(a.text)
